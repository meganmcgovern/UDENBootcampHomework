# %%
# Dependencies
import requests
from config import api_key
import time
from pprint import pprint

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Store a search term
query = "obama"

# Search for articles published between a begin and end date
begin_date = "20160101"
end_date = "20160130"

query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
print(query_url)
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=4fd4690abfaa40bbab4ecd7f76bbec42&q=obama&begin_date=20160101&end_date=20160130

# %%
pprint(articles)
# Out:
# {'copyright': 'Copyright (c) 2018 The New York Times Company. All Rights '
#               'Reserved.',
#  'response': {'docs': [{'_id': '568efce138f0d8580b9abac2',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By BARACK OBAMA',
#                                    'person': [{'firstname': 'Barack',
#                                                'lastname': 'OBAMA',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'article',
#                         'headline': {'content_kicker': 'Op-Ed Contributor',
#                                      'kicker': 'Op-Ed Contributor',
#                                      'main': 'Barack Obama: Guns Are Our '
#                                              'Shared Responsibility',
#                                      'name': None,
#                                      'print_headline': 'Our Shared '
#                                                        'Responsibility',
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 1,
#                                       'value': 'Gun Control'},
#                                      {'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 2,
#                                       'value': 'Executive Orders and '
#                                                'Memorandums'},
#                                      {'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 3,
#                                       'value': 'United States Politics and '
#                                                'Government'},
#                                      {'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 4,
#                                       'value': 'Firearms'}],
#                         'multimedia': [{'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 374,
#                                         'legacy': {'xlarge': 'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-articleLarge.jpg',
#                                                    'xlargeheight': 374,
#                                                    'xlargewidth': 600},
#                                         'rank': 0,
#                                         'subType': 'xlarge',
#                                         'subtype': 'xlarge',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-articleLarge.jpg',
#                                         'width': 600},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 126,
#                                         'legacy': {'wide': 'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-thumbWide.jpg',
#                                                    'wideheight': 126,
#                                                    'widewidth': 190},
#                                         'rank': 0,
#                                         'subType': 'wide',
#                                         'subtype': 'wide',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-thumbWide.jpg',
#                                         'width': 190},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 75,
#                                         'legacy': {'thumbnail': 'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-thumbStandard.jpg',
#                                                    'thumbnailheight': 75,
#                                                    'thumbnailwidth': 75},
#                                         'rank': 0,
#                                         'subType': 'thumbnail',
#                                         'subtype': 'thumbnail',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-thumbStandard.jpg',
#                                         'width': 75}],
#                         'news_desk': 'OpEd',
#                         'print_page': '23',
#                         'pub_date': '2016-01-08T00:03:35+0000',
#                         'score': 14.641613,
#                         'snippet': 'I will not campaign for, vote for or '
#                                    'support any candidate, even in my own '
#                                    'party, who does not support common-sense '
#                                    'gun reform.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Op-Ed',
#                         'uri': 'nyt://article/a7894d4a-24ca-5a9e-abca-616317c8b656',
#                         'web_url': 'https://www.nytimes.com/2016/01/08/opinion/president-barack-obama-guns-are-our-shared-responsibility.html',
#                         'word_count': 858},
#                        {'_id': '568f12b038f0d8580b9abb00',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'Por BARACK OBAMA',
#                                    'person': [{'firstname': 'Por',
#                                                'lastname': 'OBAMA',
#                                                'middlename': 'Barack',
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'article',
#                         'headline': {'content_kicker': 'América ',
#                                      'kicker': None,
#                                      'main': 'Barack Obama: Las armas de fuego '
#                                              'son responsabilidad de todos',
#                                      'name': None,
#                                      'print_headline': None,
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'subject',
#                                       'rank': 1,
#                                       'value': 'Gun Control'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 2,
#                                       'value': 'Executive Orders and '
#                                                'Memorandums'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 3,
#                                       'value': 'United States Politics and '
#                                                'Government'}],
#                         'multimedia': [{'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 126,
#                                         'legacy': {'wide': 'images/2016/01/08/opinion/08guns-copy-ES/08guns-thumbWide.jpg',
#                                                    'wideheight': '126',
#                                                    'widewidth': '190'},
#                                         'rank': 0,
#                                         'subType': 'wide',
#                                         'subtype': 'wide',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/08/opinion/08guns-copy-ES/08guns-thumbWide.jpg',
#                                         'width': 190},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 412,
#                                         'legacy': {'xlarge': 'images/2016/01/08/opinion/08guns-copy-ES/08guns-articleLarge.jpg',
#                                                    'xlargeheight': '412',
#                                                    'xlargewidth': '600'},
#                                         'rank': 0,
#                                         'subType': 'xlarge',
#                                         'subtype': 'xlarge',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/08/opinion/08guns-copy-ES/08guns-articleLarge.jpg',
#                                         'width': 600},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 75,
#                                         'legacy': {'thumbnail': 'images/2016/01/08/opinion/08guns-copy-ES/08guns-thumbStandard.jpg',
#                                                    'thumbnailheight': '75',
#                                                    'thumbnailwidth': '75'},
#                                         'rank': 0,
#                                         'subType': 'thumbnail',
#                                         'subtype': 'thumbnail',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/08/opinion/08guns-copy-ES/08guns-thumbStandard.jpg',
#                                         'width': 75}],
#                         'news_desk': 'OpEd',
#                         'pub_date': '2016-01-08T00:00:00Z',
#                         'score': 14.390729,
#                         'section_name': 'América',
#                         'snippet': 'Todos –gobierno, sector privado y los '
#                                    'ciudadanos– debemos hacer un frente común '
#                                    'para acabar con esta violencia sin '
#                                    'sentido.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Op-Ed',
#                         'web_url': 'https://www.nytimes.com/2016/01/08/universal/es/president-barack-obama-guns-are-our-shared-responsibility.html',
#                         'word_count': 994},
#                        {'_id': '56a5db0238f0d81529067d20',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By DAVID AXELROD',
#                                    'person': [{'firstname': 'David',
#                                                'lastname': 'AXELROD',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'article',
#                         'headline': {'content_kicker': 'Op-Ed Contributor',
#                                      'kicker': 'Op-Ed Contributor',
#                                      'main': 'The Obama Theory of Trump',
#                                      'name': None,
#                                      'print_headline': 'The Obama Theory of '
#                                                        'Trump',
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 1,
#                                       'value': 'Presidential Election of 2016'},
#                                      {'major': 'N',
#                                       'name': 'persons',
#                                       'rank': 2,
#                                       'value': 'Trump, Donald J'},
#                                      {'major': 'N',
#                                       'name': 'persons',
#                                       'rank': 3,
#                                       'value': 'Obama, Barack'},
#                                      {'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 4,
#                                       'value': 'United States Politics and '
#                                                'Government'},
#                                      {'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 5,
#                                       'value': 'Polls and Public Opinion'},
#                                      {'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 6,
#                                       'value': 'Voting and Voters'},
#                                      {'major': 'N',
#                                       'name': 'organizations',
#                                       'rank': 7,
#                                       'value': 'Republican Party'}],
#                         'multimedia': [{'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 393,
#                                         'legacy': {'xlarge': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-articleLarge.jpg',
#                                                    'xlargeheight': 393,
#                                                    'xlargewidth': 600},
#                                         'rank': 0,
#                                         'subType': 'xlarge',
#                                         'subtype': 'xlarge',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-articleLarge.jpg',
#                                         'width': 600},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 126,
#                                         'legacy': {'wide': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-thumbWide.jpg',
#                                                    'wideheight': 126,
#                                                    'widewidth': 190},
#                                         'rank': 0,
#                                         'subType': 'wide',
#                                         'subtype': 'wide',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-thumbWide.jpg',
#                                         'width': 190},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 75,
#                                         'legacy': {'thumbnail': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-thumbStandard.jpg',
#                                                    'thumbnailheight': 75,
#                                                    'thumbnailwidth': 75},
#                                         'rank': 0,
#                                         'subType': 'thumbnail',
#                                         'subtype': 'thumbnail',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-thumbStandard.jpg',
#                                         'width': 75}],
#                         'news_desk': 'OpEd',
#                         'print_page': '21',
#                         'pub_date': '2016-01-25T08:21:17+0000',
#                         'score': 14.108012,
#                         'section_name': 'Campaign Stops',
#                         'snippet': 'In presidential elections, opposites '
#                                    'attract.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Op-Ed',
#                         'uri': 'nyt://article/ae224f9a-e4c5-53b7-9681-905a15bbc393',
#                         'web_url': 'https://www.nytimes.com/2016/01/25/opinion/campaign-stops/the-obama-theory-of-trump.html',
#                         'word_count': 1078},
#                        {'_id': '569365fc38f0d801cf86fb39',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By PAUL KRUGMAN',
#                                    'person': [{'firstname': 'Paul',
#                                                'lastname': 'KRUGMAN',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'article',
#                         'headline': {'content_kicker': 'Op-Ed Columnist',
#                                      'kicker': 'Op-Ed Columnist',
#                                      'main': 'The Obama Boom',
#                                      'name': None,
#                                      'print_headline': 'The  Obama  Boom',
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 1,
#                                       'value': 'United States Economy'},
#                                      {'major': 'N',
#                                       'name': 'persons',
#                                       'rank': 2,
#                                       'value': 'Obama, Barack'},
#                                      {'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 3,
#                                       'value': 'Labor and Jobs'},
#                                      {'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 4,
#                                       'value': 'United States Politics and '
#                                                'Government'}],
#                         'multimedia': [{'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 400,
#                                         'legacy': {'xlarge': 'images/2016/01/11/opinion/11krugmanWeb/11krugmanWeb-articleLarge.jpg',
#                                                    'xlargeheight': 400,
#                                                    'xlargewidth': 600},
#                                         'rank': 0,
#                                         'subType': 'xlarge',
#                                         'subtype': 'xlarge',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/11/opinion/11krugmanWeb/11krugmanWeb-articleLarge.jpg',
#                                         'width': 600},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 126,
#                                         'legacy': {'wide': 'images/2016/01/11/opinion/11krugmanWeb/11krugmanWeb-thumbWide.jpg',
#                                                    'wideheight': 126,
#                                                    'widewidth': 190},
#                                         'rank': 0,
#                                         'subType': 'wide',
#                                         'subtype': 'wide',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/11/opinion/11krugmanWeb/11krugmanWeb-thumbWide.jpg',
#                                         'width': 190},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 75,
#                                         'legacy': {'thumbnail': 'images/2016/01/11/opinion/11krugmanWeb/11krugmanWeb-thumbStandard.jpg',
#                                                    'thumbnailheight': 75,
#                                                    'thumbnailwidth': 75},
#                                         'rank': 0,
#                                         'subType': 'thumbnail',
#                                         'subtype': 'thumbnail',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/11/opinion/11krugmanWeb/11krugmanWeb-thumbStandard.jpg',
#                                         'width': 75}],
#                         'news_desk': 'OpEd',
#                         'print_page': '23',
#                         'pub_date': '2016-01-11T08:21:05+0000',
#                         'score': 12.776971,
#                         'snippet': 'Dire warnings from Republicans about the '
#                                    'effect of President Obama’s policies on '
#                                    'employment have simply not come true.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Op-Ed',
#                         'uri': 'nyt://article/96cc9aff-1806-51ba-8dee-9fff728009f2',
#                         'web_url': 'https://www.nytimes.com/2016/01/11/opinion/the-obama-boom.html',
#                         'word_count': 803},
#                        {'_id': '56981f5238f0d8108a7eb756',
#                         'blog': {},
#                         'byline': {'organization': 'THE ASSOCIATED PRESS',
#                                    'original': 'By THE ASSOCIATED PRESS',
#                                    'person': []},
#                         'document_type': 'multimedia',
#                         'headline': {'content_kicker': None,
#                                      'kicker': None,
#                                      'main': 'Obama On the Road',
#                                      'name': None,
#                                      'print_headline': None,
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'persons',
#                                       'rank': 1,
#                                       'value': 'Obama, Barack'}],
#                         'multimedia': [{'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 126,
#                                         'legacy': {'wide': 'images/2016/01/15/us/15obama1_hp/15obama1_hp-thumbWide-v2.jpg',
#                                                    'wideheight': '126',
#                                                    'widewidth': '190'},
#                                         'rank': 0,
#                                         'subType': 'wide',
#                                         'subtype': 'wide',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/15/us/15obama1_hp/15obama1_hp-thumbWide-v2.jpg',
#                                         'width': 190},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 337,
#                                         'legacy': {'xlarge': 'images/2016/01/15/us/15obama1_hp/15obama1_hp-articleLarge-v2.jpg',
#                                                    'xlargeheight': '337',
#                                                    'xlargewidth': '600'},
#                                         'rank': 0,
#                                         'subType': 'xlarge',
#                                         'subtype': 'xlarge',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/15/us/15obama1_hp/15obama1_hp-articleLarge-v2.jpg',
#                                         'width': 600},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 75,
#                                         'legacy': {'thumbnail': 'images/2016/01/15/us/15obama1_hp/15obama1_hp-thumbStandard.jpg',
#                                                    'thumbnailheight': '75',
#                                                    'thumbnailwidth': '75'},
#                                         'rank': 0,
#                                         'subType': 'thumbnail',
#                                         'subtype': 'thumbnail',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/15/us/15obama1_hp/15obama1_hp-thumbStandard.jpg',
#                                         'width': 75}],
#                         'news_desk': 'U.S.',
#                         'pub_date': '2016-01-14T16:44:35Z',
#                         'score': 11.721747,
#                         'snippet': 'Highlights from President Obama’s remarks '
#                                    'at a town-hall style meeting in Baton '
#                                    'Rouge, La, on Thursday.',
#                         'source': 'AP',
#                         'type_of_material': 'Video',
#                         'web_url': 'https://www.nytimes.com/video/us/100000004145097/obama-on-the-road.html',
#                         'word_count': 16},
#                        {'_id': '5697db3738f0d8108a7eb67d',
#                         'abstract': '“Let me tell you, there are three things '
#                                     'that are certain in life: death, taxes, '
#                                     'and Michelle is not running for '
#                                     'president.” — President Obama',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By FIRST DRAFT',
#                                    'person': [{'firstname': 'First',
#                                                'lastname': 'DRAFT',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'blogpost',
#                         'headline': {'content_kicker': None,
#                                      'kicker': 'First Draft',
#                                      'main': 'Verbatim: Barack Obama on '
#                                              'Michelle Obama&#8217;s '
#                                              'Presidential Ambitions',
#                                      'name': None,
#                                      'print_headline': None,
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'persons',
#                                       'rank': 1,
#                                       'value': 'Obama, Barack'},
#                                      {'major': None,
#                                       'name': 'persons',
#                                       'rank': 2,
#                                       'value': 'Obama, Michelle'},
#                                      {'major': None,
#                                       'name': 'glocations',
#                                       'rank': 1,
#                                       'value': 'Baton Rouge (La)'}],
#                         'multimedia': [],
#                         'news_desk': 'Politics',
#                         'pub_date': '2016-01-14T12:28:54Z',
#                         'score': 11.643919,
#                         'section_name': 'Politics',
#                         'snippet': '“Let me tell you, there are three things '
#                                    'that are certain in life: death, taxes, '
#                                    'and Michelle is not running for '
#                                    'president.” — President Obama',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Blog',
#                         'web_url': 'https://www.nytimes.com/politics/first-draft/2016/01/14/verbatim-barack-obama-on-michelle-obamas-presidential-ambitions/',
#                         'word_count': 74},
#                        {'_id': '56975a8638f0d865e6c34a6c',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By CHARLES M. BLOW',
#                                    'person': [{'firstname': 'Charles',
#                                                'lastname': None,
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'article',
#                         'headline': {'content_kicker': 'Op-Ed Columnist',
#                                      'kicker': 'Op-Ed Columnist',
#                                      'main': 'The Other Obama Legacy',
#                                      'name': None,
#                                      'print_headline': 'The Other Obama Legacy',
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 1,
#                                       'value': 'Blacks'},
#                                      {'major': 'N',
#                                       'name': 'persons',
#                                       'rank': 2,
#                                       'value': 'Obama, Barack'},
#                                      {'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 3,
#                                       'value': 'United States Politics and '
#                                                'Government'},
#                                      {'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 4,
#                                       'value': 'Education (K-12)'},
#                                      {'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 5,
#                                       'value': 'Youth'},
#                                      {'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 6,
#                                       'value': 'Polls and Public Opinion'}],
#                         'multimedia': [{'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 404,
#                                         'legacy': {'xlarge': 'images/2016/01/14/opinion/14blowWeb/14blowWeb-articleLarge.jpg',
#                                                    'xlargeheight': 404,
#                                                    'xlargewidth': 600},
#                                         'rank': 0,
#                                         'subType': 'xlarge',
#                                         'subtype': 'xlarge',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/14/opinion/14blowWeb/14blowWeb-articleLarge.jpg',
#                                         'width': 600},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 126,
#                                         'legacy': {'wide': 'images/2016/01/14/opinion/14blowWeb/14blowWeb-thumbWide.jpg',
#                                                    'wideheight': 126,
#                                                    'widewidth': 190},
#                                         'rank': 0,
#                                         'subType': 'wide',
#                                         'subtype': 'wide',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/14/opinion/14blowWeb/14blowWeb-thumbWide.jpg',
#                                         'width': 190},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 75,
#                                         'legacy': {'thumbnail': 'images/2016/01/14/opinion/14blowWeb/14blowWeb-thumbStandard.jpg',
#                                                    'thumbnailheight': 75,
#                                                    'thumbnailwidth': 75},
#                                         'rank': 0,
#                                         'subType': 'thumbnail',
#                                         'subtype': 'thumbnail',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/14/opinion/14blowWeb/14blowWeb-thumbStandard.jpg',
#                                         'width': 75}],
#                         'news_desk': 'OpEd',
#                         'pub_date': '2016-01-14T08:21:23+0000',
#                         'score': 11.41419,
#                         'snippet': 'For many young people, the first president '
#                                    'they consciously registered was a black '
#                                    'man.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Op-Ed',
#                         'uri': 'nyt://article/a0fb8c8b-8e46-5938-b26c-92c1e76bec80',
#                         'web_url': 'https://www.nytimes.com/2016/01/14/opinion/the-other-obama-legacy.html',
#                         'word_count': 951},
#                        {'_id': '5696a41e38f0d865e6c34875',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': None,
#                                    'person': None},
#                         'document_type': 'article',
#                         'headline': {'content_kicker': 'Letters',
#                                      'kicker': 'Letters',
#                                      'main': 'Obama’s Final State of the Union '
#                                              'Speech',
#                                      'name': None,
#                                      'print_headline': 'Obama’s Final State of '
#                                                        'the Union',
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'subject',
#                                       'rank': 1,
#                                       'value': 'State of the Union Message '
#                                                '(US)'},
#                                      {'major': None,
#                                       'name': 'persons',
#                                       'rank': 2,
#                                       'value': 'Obama, Barack'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 3,
#                                       'value': 'United States Politics and '
#                                                'Government'}],
#                         'multimedia': [{'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 126,
#                                         'legacy': {'wide': 'images/2016/01/14/opinion/14LobamaWeb/14LobamaWeb-thumbWide.jpg',
#                                                    'wideheight': '126',
#                                                    'widewidth': '190'},
#                                         'rank': 0,
#                                         'subType': 'wide',
#                                         'subtype': 'wide',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/14/opinion/14LobamaWeb/14LobamaWeb-thumbWide.jpg',
#                                         'width': 190},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 400,
#                                         'legacy': {'xlarge': 'images/2016/01/14/opinion/14LobamaWeb/14LobamaWeb-articleLarge.jpg',
#                                                    'xlargeheight': '400',
#                                                    'xlargewidth': '600'},
#                                         'rank': 0,
#                                         'subType': 'xlarge',
#                                         'subtype': 'xlarge',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/14/opinion/14LobamaWeb/14LobamaWeb-articleLarge.jpg',
#                                         'width': 600},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 75,
#                                         'legacy': {'thumbnail': 'images/2016/01/14/opinion/14LobamaWeb/14LobamaWeb-thumbStandard.jpg',
#                                                    'thumbnailheight': '75',
#                                                    'thumbnailwidth': '75'},
#                                         'rank': 0,
#                                         'subType': 'thumbnail',
#                                         'subtype': 'thumbnail',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/14/opinion/14LobamaWeb/14LobamaWeb-thumbStandard.jpg',
#                                         'width': 75}],
#                         'news_desk': 'Letters',
#                         'print_page': '26',
#                         'pub_date': '2016-01-14T00:00:00Z',
#                         'score': 11.303803,
#                         'snippet': 'Readers mostly praise the president’s '
#                                    'speech as hopeful and inclusive.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Letter',
#                         'web_url': 'https://www.nytimes.com/2016/01/14/opinion/obamas-final-state-of-the-union-speech.html',
#                         'word_count': 645},
#                        {'_id': '569ffdc138f0d80627b20b1a',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': None,
#                                    'person': None},
#                         'document_type': 'article',
#                         'headline': {'content_kicker': 'Letters',
#                                      'kicker': 'Letters',
#                                      'main': 'Did Obama Overstep His Authority '
#                                              'on Immigration?',
#                                      'name': None,
#                                      'print_headline': 'Did Obama Overstep His '
#                                                        'Authority?',
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'subject',
#                                       'rank': 1,
#                                       'value': 'Immigration and Emigration'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 2,
#                                       'value': 'Executive Orders and '
#                                                'Memorandums'},
#                                      {'major': None,
#                                       'name': 'persons',
#                                       'rank': 3,
#                                       'value': 'Obama, Barack'},
#                                      {'major': None,
#                                       'name': 'organizations',
#                                       'rank': 4,
#                                       'value': 'Supreme Court (US)'}],
#                         'multimedia': [{'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 126,
#                                         'legacy': {'wide': 'images/2016/01/21/opinion/21LscotusWeb/21LscotusWeb-thumbWide.jpg',
#                                                    'wideheight': '126',
#                                                    'widewidth': '190'},
#                                         'rank': 0,
#                                         'subType': 'wide',
#                                         'subtype': 'wide',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/21/opinion/21LscotusWeb/21LscotusWeb-thumbWide.jpg',
#                                         'width': 190},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 400,
#                                         'legacy': {'xlarge': 'images/2016/01/21/opinion/21LscotusWeb/21LscotusWeb-articleLarge.jpg',
#                                                    'xlargeheight': '400',
#                                                    'xlargewidth': '600'},
#                                         'rank': 0,
#                                         'subType': 'xlarge',
#                                         'subtype': 'xlarge',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/21/opinion/21LscotusWeb/21LscotusWeb-articleLarge.jpg',
#                                         'width': 600},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 75,
#                                         'legacy': {'thumbnail': 'images/2016/01/21/opinion/21LscotusWeb/21LscotusWeb-thumbStandard.jpg',
#                                                    'thumbnailheight': '75',
#                                                    'thumbnailwidth': '75'},
#                                         'rank': 0,
#                                         'subType': 'thumbnail',
#                                         'subtype': 'thumbnail',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/21/opinion/21LscotusWeb/21LscotusWeb-thumbStandard.jpg',
#                                         'width': 75}],
#                         'news_desk': 'Letters',
#                         'print_page': '26',
#                         'pub_date': '2016-01-21T00:00:00Z',
#                         'score': 10.968107,
#                         'snippet': 'Readers discuss the Supreme Court’s '
#                                    'decision to hear a case challenging the '
#                                    'president’s executive actions.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Letter',
#                         'web_url': 'https://www.nytimes.com/2016/01/21/opinion/did-obama-overstep-his-authority-on-immigration.html',
#                         'word_count': 535},
#                        {'_id': '56a6dc6338f0d82e672489c9',
#                         'abstract': 'Pres Obama, based on Justice Dept '
#                                     'recommendation, issues prohibition '
#                                     'against keeping juveniles in solitary '
#                                     'confinement in federal prisons; president '
#                                     'has been increasingly aggressive on '
#                                     'criminal justice and correctional '
#                                     'policies that are viewed as biased '
#                                     'against blacks and other minorities.',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By MICHAEL D. SHEAR',
#                                    'person': [{'firstname': 'Michael',
#                                                'lastname': None,
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'article',
#                         'headline': {'content_kicker': None,
#                                      'kicker': None,
#                                      'main': 'Obama Bans Solitary Confinement '
#                                              'of Juveniles in Federal Prisons',
#                                      'name': None,
#                                      'print_headline': 'Obama Bans Federal '
#                                                        'Solitary Confinement '
#                                                        'for Youths',
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'subject',
#                                       'rank': 1,
#                                       'value': 'Prisons and Prisoners'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 2,
#                                       'value': 'Solitary Confinement'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 3,
#                                       'value': 'Juvenile Delinquency'},
#                                      {'major': None,
#                                       'name': 'persons',
#                                       'rank': 4,
#                                       'value': 'Obama, Barack'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 5,
#                                       'value': 'Blacks'},
#                                      {'major': None,
#                                       'name': 'organizations',
#                                       'rank': 6,
#                                       'value': 'Federal Bureau of Prisons'}],
#                         'multimedia': [{'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 126,
#                                         'legacy': {'wide': 'images/2016/01/26/us/26solitary-web/26solitary-web-thumbWide.jpg',
#                                                    'wideheight': '126',
#                                                    'widewidth': '190'},
#                                         'rank': 0,
#                                         'subType': 'wide',
#                                         'subtype': 'wide',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/26/us/26solitary-web/26solitary-web-thumbWide.jpg',
#                                         'width': 190},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 366,
#                                         'legacy': {'xlarge': 'images/2016/01/26/us/26solitary-web/26solitary-web-articleLarge.jpg',
#                                                    'xlargeheight': '366',
#                                                    'xlargewidth': '600'},
#                                         'rank': 0,
#                                         'subType': 'xlarge',
#                                         'subtype': 'xlarge',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/26/us/26solitary-web/26solitary-web-articleLarge.jpg',
#                                         'width': 600},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 75,
#                                         'legacy': {'thumbnail': 'images/2016/01/26/us/26solitary-web/26solitary-web-thumbStandard.jpg',
#                                                    'thumbnailheight': '75',
#                                                    'thumbnailwidth': '75'},
#                                         'rank': 0,
#                                         'subType': 'thumbnail',
#                                         'subtype': 'thumbnail',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/26/us/26solitary-web/26solitary-web-thumbStandard.jpg',
#                                         'width': 75}],
#                         'news_desk': 'National',
#                         'print_page': '18',
#                         'pub_date': '2016-01-26T00:00:00Z',
#                         'score': 10.90107,
#                         'section_name': 'Politics',
#                         'snippet': 'The practice can lead to “devastating, '
#                                    'lasting psychological consequences,” he '
#                                    'said in an opinion article in The '
#                                    'Washington Post.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'News',
#                         'web_url': 'https://www.nytimes.com/2016/01/26/us/politics/obama-bans-solitary-confinement-of-juveniles-in-federal-prisons.html',
#                         'word_count': 905}],
#               'meta': {'hits': 748, 'offset': 0, 'time': 10}},
#  'status': 'OK'}

# %%
# Retrieve articles
articles = requests.get(query_url).json()
articles_list = [article for article in articles["response"]["docs"]]

for article in articles_list:
    print(f'A snippet from the article: {article["snippet"]}')
# Out:
# A snippet from the article: I will not campaign for, vote for or support any candidate, even in my own party, who does not support common-sense gun reform.
# A snippet from the article: Todos –gobierno, sector privado y los ciudadanos– debemos hacer un frente común para acabar con esta violencia sin sentido.
# A snippet from the article: In presidential elections, opposites attract.
# A snippet from the article: Dire warnings from Republicans about the effect of President Obama’s policies on employment have simply not come true.
# A snippet from the article: Highlights from President Obama’s remarks at a town-hall style meeting in Baton Rouge, La, on Thursday.
# A snippet from the article: “Let me tell you, there are three things that are certain in life: death, taxes, and Michelle is not running for president.” — President Obama
# A snippet from the article: For many young people, the first president they consciously registered was a black man.
# A snippet from the article: Readers mostly praise the president’s speech as hopeful and inclusive.
# A snippet from the article: Readers discuss the Supreme Court’s decision to hear a case challenging the president’s executive actions.
# A snippet from the article: The practice can lead to “devastating, lasting psychological consequences,” he said in an opinion article in The Washington Post.

# %%
# BONUS: How would we get 30 results? 
# HINT: Look up the page query param

# Emply list for articles
articles_list = []

# loop through pages 0-2
for page in range(0, 3):
    query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
    # create query with page number
    query_url = f"{query_url}&page={str(page)}"
    articles = requests.get(query_url).json()
    
    # Add a one second interval between queries to stay within API query limits
    time.sleep(1)
    # loop through the response and append each article to the list
    for article in articles["response"]["docs"]:
        articles_list.append(article)
